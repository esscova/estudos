# %%
# bibliotecas
install.packages("ppclust")
library(ppclust)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘kpeaks’, ‘lhs’, ‘inaparc’

# %%
# carregando dados
data(iris)

# %%
# primeiras linhas
head(iris)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %%
# algoritmo FCM com k=3
fcm <- fcm(iris[,-5], centers=3)

# %%
# resultados
print(fcm)
# Out:
# $u
#        Cluster 1    Cluster 2   Cluster 3
# 1   0.0023043797 0.0010720343 0.996623586
# 2   0.0166495094 0.0074979471 0.975852543
# 3   0.0137594999 0.0064145785 0.979825922
# 4   0.0224650314 0.0101075228 0.967427446
# 5   0.0037617094 0.0017679352 0.994470355
# 6   0.0448062334 0.0206196544 0.934574112
# 7   0.0140038150 0.0065045178 0.979491667
# 8   0.0003115325 0.0001412048 0.999547263
# 9   0.0477177955 0.0219024180 0.930379787
# 10  0.0119354753 0.0053415614 0.982722963
# 11  0.0217567454 0.0102009404 0.968042314
# 12  0.0054317837 0.0024310579 0.992137158
# 13  0.0201826777 0.0091771718 0.970640151
# 14  0.0517941280 0.0252359838 0.922969888
# 15  0.0726093846 0.0376316556 0.889758960
# 16  0.1043490942 0.0543059146 0.841344991
# 17  0.0355790790 0.0174955672 0.946925354
# 18  0.0022884844 0.0010587888 0.996652727
# 19  0.0655566844 0.0303079325 0.904135383
# 20  0.0141573036 0.0066536393 0.979189057
# 21  0.0218552641 0.0095402581 0.968604478
# ...

# %%
# plot
plotcluster(fcm)
# Out:
# plot without title
